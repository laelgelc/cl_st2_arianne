# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 2 - Phase 3

# %% [markdown]
# This phase aims to compile a [Greenpeace Stories](https://www.greenpeace.org/international/story/) corpus for CAD 2026 and IVACS 2026.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Import the required libraries

# %%
import pandas as pd
import os
import sys
import logging

# %% [markdown]
# ## Define input variables

# %%
input_directory = 'cl_st2_ph1_arianne'
output_directory = 'cl_st2_ph2_arianne'

# %% [markdown]
# ## Create output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory already exists.

# %% [markdown]
# ## Set up logging

# %%
log_filename = f"{output_directory}/{output_directory}.log"

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename=log_filename
)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Create output subdirectories

# %%
def create_directory(path):
    """Creates a subdirectory if it doesn't exist."""
    if not os.path.exists(path):
        try:
            os.makedirs(path)
            print(f"Successfully created the directory: {path}")
        except OSError as e:
            print(f"Failed to create the {path} directory: {e}")
            sys.exit(1)
    else:
        print(f"Directory already exists: {path}")

# %% [markdown]
# ## Data Wrangling [Greenpeace Stories](https://www.greenpeace.org/international/story/)

# %% [markdown]
# ### Define local variables

# %%
id = 'grp'
extracted_dir = '02_extracted'
path = os.path.join(output_directory, id, extracted_dir)
dataset_filename_1 = f"{id}_list"
dataset_filename_2 = f"{id}"
dataset_filename_3 = f"{id}_1000"

# %% [markdown]
# ### Create output subdirectory

# %%
create_directory(path)
# Out:
# Directory already exists: cl_st2_ph2_arianne/grp/02_extracted

# %% [markdown]
# ### Import the data into a DataFrame

# %%
df_grp_paragraph = pd.read_json(f"{input_directory}/{dataset_filename_2}.jsonl", lines=True)

# %%
df_grp_paragraph['Post Date'] = pd.to_datetime(df_grp_paragraph['Post Date'], unit='ms')

# %%
df_grp_paragraph
# Out:
#            Source Post Term         Post Tags  \
# 0      Greenpeace   Stories       Photography
# 1      Greenpeace   Stories       Photography
# 2      Greenpeace   Stories       Photography
# 3      Greenpeace   Stories       Photography
# 4      Greenpeace   Stories       Photography
# ...           ...       ...               ...
# 23415  Greenpeace   Stories  AboutUs, 50Years
# 23416  Greenpeace   Stories  AboutUs, 50Years
# 23417  Greenpeace   Stories  AboutUs, 50Years
# 23418  Greenpeace   Stories  AboutUs, 50Years
# 23419  Greenpeace   Stories  AboutUs, 50Years
#
#                                  Title  \
# 0      Greenpeace Pictures of the Week
# 1      Greenpeace Pictures of the Week
# 2      Greenpeace Pictures of the Week
# 3      Greenpeace Pictures of the Week
# 4      Greenpeace Pictures of the Week
# ...                                ...
# 23415           Bob Hunter 1941 – 2005
# 23416           Bob Hunter 1941 – 2005
# 23417           Bob Hunter 1941 – 2005
# 23418           Bob Hunter 1941 – 2005
# 23419           Bob Hunter 1941 – 2005
#
#                                                 Post URL  \
# 0      https://www.greenpeace.org/international/story...
# 1      https://www.greenpeace.org/international/story...
# 2      https://www.greenpeace.org/international/story...
# 3      https://www.greenpeace.org/international/story...
# 4      https://www.greenpeace.org/international/story...
# ...                                                  ...
# 23415  https://www.greenpeace.org/international/story...
# 23416  https://www.greenpeace.org/international/story...
# 23417  https://www.greenpeace.org/international/story...
# 23418  https://www.greenpeace.org/international/story...
# 23419  https://www.greenpeace.org/international/story...
#
#                         Authors           Post Date    Post ID    Category  \
# 0      Greenpeace International 2025-08-15 01:45:33  grp000000  Greenpeace
# 1      Greenpeace International 2025-08-15 01:45:33  grp000000  Greenpeace
# 2      Greenpeace International 2025-08-15 01:45:33  grp000000  Greenpeace
# 3      Greenpeace International 2025-08-15 01:45:33  grp000000  Greenpeace
# 4      Greenpeace International 2025-08-15 01:45:33  grp000000  Greenpeace
# ...                         ...                 ...        ...         ...
# 23415  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
# 23416  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
# 23417  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
# 23418  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
# 23419  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
#
#           Paragraph                                     Text Paragraph
# 0       Paragraph 1  From a banner protest at the plastic treaty in...
# 1       Paragraph 2  🇬🇧 England – Greenpeace UK’s climbers install ...
# 2       Paragraph 3  After securing a giant 12m x 8m canvas to one ...
# 3       Paragraph 4  The work starkly visualises the wound inflicte...
# 4       Paragraph 5  🇨🇭 Switzerland – Juan Carlos Monterrey Gómez, ...
# ...             ...                                                ...
# 23415  Paragraph 13  He joined Toronto’s City TV as an ecology spec...
# 23416  Paragraph 14  Over the years he continued to contribute to G...
# 23417  Paragraph 15  In a recent book, Rex Weyler writes about refl...
# 23418  Paragraph 16  “The ironies and tension of history simultaneo...
# 23419  Paragraph 17  Bob Hunter made much of his opportunity to ser...
#
# [23420 rows x 11 columns]

# %% [markdown]
# ### Reassemble the blog posts from the paragraphs

# %% [markdown]
# To address your request, I will group the `df_grp_paragraph` DataFrame by `Post ID`, sort the paragraphs within each group based on the `Paragraph` identifier to ensure correct order, and then join the text content from `Text Paragraph` with newline characters. Finally, I'll merge this aggregated text back with the original metadata columns while dropping the individual paragraph-related columns.

# %%
# Sort by Post ID and Paragraph to ensure correct order
df_grp_paragraph_sorted = df_grp_paragraph.sort_values(by=['Post ID', 'Paragraph'])

# Group by Post ID and join the Text Paragraphs with a newline
df_grp_texts = df_grp_paragraph_sorted.groupby('Post ID')['Text Paragraph'].apply(lambda x: '\n'.join(x)).reset_index()
df_grp_texts.rename(columns={'Text Paragraph': 'Text'}, inplace=True)

# Merge the reassembled text back with the original metadata (dropping paragraph specific columns first to avoid duplicates)
# We keep the first occurrence of metadata for each Post ID
df_grp_metadata = df_grp_paragraph_sorted.drop(columns=['Paragraph', 'Text Paragraph']).drop_duplicates(
    subset=['Post ID'])

# Create the final df_grp DataFrame
df_grp = pd.merge(df_grp_metadata, df_grp_texts, on='Post ID')

df_grp
# Out:
#           Source Post Term           Post Tags  \
# 0     Greenpeace   Stories         Photography
# 1     Greenpeace   Stories             Forests
# 2     Greenpeace   Stories  AlternativeFutures
# 3     Greenpeace   Stories         Photography
# 4     Greenpeace   Stories      Peace, Nuclear
# ...          ...       ...                 ...
# 1352  Greenpeace   Stories    AboutUs, 50Years
# 1353  Greenpeace   Stories    AboutUs, 50Years
# 1354  Greenpeace   Stories    AboutUs, 50Years
# 1355  Greenpeace   Stories    AboutUs, 50Years
# 1356  Greenpeace   Stories    AboutUs, 50Years
#
#                                                   Title  \
# 0                       Greenpeace Pictures of the Week
# 1     Environmental storytelling for a Chinese audie...
# 2     5 reasons Greenpeace calls for new global tax ...
# 3                       Greenpeace Pictures of the Week
# 4               From Hiroshima to Gaza: defending peace
# ...                                                 ...
# 1352                          Dorothy Stowe 1920 – 2010
# 1353                             Jim Bohlen 1926 – 2010
# 1354             A chat with the first Rainbow Warriors
# 1355                      Amchitka: the founding voyage
# 1356                             Bob Hunter 1941 – 2005
#
#                                                Post URL  \
# 0     https://www.greenpeace.org/international/story...
# 1     https://www.greenpeace.org/international/story...
# 2     https://www.greenpeace.org/international/story...
# 3     https://www.greenpeace.org/international/story...
# 4     https://www.greenpeace.org/international/story...
# ...                                                 ...
# 1352  https://www.greenpeace.org/international/story...
# 1353  https://www.greenpeace.org/international/story...
# 1354  https://www.greenpeace.org/international/story...
# 1355  https://www.greenpeace.org/international/story...
# 1356  https://www.greenpeace.org/international/story...
#
#                        Authors           Post Date    Post ID  \
# 0     Greenpeace International 2025-08-15 01:45:33  grp000000
# 1                  August Rick 2025-08-14 01:40:25  grp000001
# 2                   Nina Stros 2025-08-13 13:47:04  grp000002
# 3     Greenpeace International 2025-08-08 05:09:19  grp000003
# 4            Greenpeace France 2025-08-07 15:22:58  grp000004
# ...                        ...                 ...        ...
# 1352                Rex Weyler 2010-07-23 07:48:13  grp001352
# 1353  Greenpeace International 2010-07-06 08:06:09  grp001353
# 1354         Michael Friedrich 2007-06-24 12:03:00  grp001354
# 1355  Greenpeace International 2007-05-14 13:56:16  grp001355
# 1356  Greenpeace International 2005-05-02 15:15:00  grp001356
#
#                          Category  \
# 0                      Greenpeace
# 1                          Nature
# 2     Social and Economic Systems
# 3                      Greenpeace
# 4                          Energy
# ...                           ...
# 1352                   Greenpeace
# 1353                   Greenpeace
# 1354                   Greenpeace
# 1355                   Greenpeace
# 1356                   Greenpeace
#
#                                                    Text
# 0     From a banner protest at the plastic treaty in...
# 1     Liu Min, better known as “Aunt Bear”, was one ...
# 2     Smoke from the Canadian wildfires drifting thr...
# 3     From a demonstration at the plastic treaty in ...
# 4     On August 6 and 9, 1945, two atomic bombs pulv...
# ...                                                 ...
# 1352  Greenpeace co-founder Dorothy Stowe passed awa...
# 1353  There’s an old joke that you can walk into any...
# 1354  In Vancouver, on Canada’s Pacific coast, Green...
# 1355  In 1971, a small group of activists set sail t...
# 1356  Perhaps more than anyone else, Bob Hunter inve...
#
# [1357 rows x 10 columns]

# %% [markdown]
# ### Identifying potential fragments

# %% [markdown]
# The user wants to filter the `df_grp` DataFrame to find rows where the `Text` column contains only one paragraph. Since the text was constructed by joining paragraphs with a newline character (`\n`), a single paragraph is characterized by the absence of newline characters in the `Text` column.

# %%
# Identify rows where the 'Text' column consists of a single paragraph
# Since paragraphs were joined by '\n', a single paragraph implies no newline characters are present
df_grp_single_paragraph = df_grp[df_grp['Text'].str.count('\n') == 0]
df_grp_single_paragraph
# Out:
#           Source Post Term                                        Post Tags  \
# 118   Greenpeace   Stories  ArcticSunrise, RainbowWarrior, Witness, AboutUs
# 962   Greenpeace   Stories                                          Climate
# 1031  Greenpeace   Stories                                          Climate
# 1210  Greenpeace   Stories                        Consumption, Food, Health
#
#                                                   Title  \
# 118                       Best of Greenpeace ships 2024
# 962   Amidst this climate crisis, I found hope from ...
# 1031  A super-charged typhoon took my family away. I...
# 1210  Seeing is believing: Growing food for people, ...
#
#                                                Post URL  \
# 118   https://www.greenpeace.org/international/story...
# 962   https://www.greenpeace.org/international/story...
# 1031  https://www.greenpeace.org/international/story...
# 1210  https://www.greenpeace.org/international/story...
#
#                      Authors           Post Date    Post ID  \
# 118       Sudhanshu Malhotra 2024-12-18 07:55:26  grp000118
# 962    Nanticha Ocharoenchai 2019-05-01 02:36:13  grp000962
# 1031  Rashini Suriyaarachchi 2018-10-09 05:06:43  grp001031
# 1210            Reyes Tirado 2017-01-13 00:31:00  grp001210
#
#                          Category  \
# 118                    Greenpeace
# 962   Social and Economic Systems
# 1031  Social and Economic Systems
# 1210                       Nature
#
#                                                    Text
# 118   Our ships are a source of strength for million...
# 962        All it took was determination and initiative
# 1031  Many of us think about the impacts of climate ...
# 1210  “Ojos hacen fe.” Those are the words of Lucy M...

# %% [markdown]
# Only row 118 is not a fragment and should not be excluded.

# %% [markdown]
# The user wants to remove the row with index `118` from the `df_grp_single_paragraph` DataFrame. This DataFrame currently holds rows identified as single-paragraph posts (potential fragments), but according to the previous markdown cell, row 118 is valid and should be kept in the main dataset (meaning it should be removed from this "to-delete" list).

# %%
# Drop row 118 from df_grp_single_paragraph
df_grp_single_paragraph = df_grp_single_paragraph.drop(118)
df_grp_single_paragraph
# Out:
#           Source Post Term                  Post Tags  \
# 962   Greenpeace   Stories                    Climate
# 1031  Greenpeace   Stories                    Climate
# 1210  Greenpeace   Stories  Consumption, Food, Health
#
#                                                   Title  \
# 962   Amidst this climate crisis, I found hope from ...
# 1031  A super-charged typhoon took my family away. I...
# 1210  Seeing is believing: Growing food for people, ...
#
#                                                Post URL  \
# 962   https://www.greenpeace.org/international/story...
# 1031  https://www.greenpeace.org/international/story...
# 1210  https://www.greenpeace.org/international/story...
#
#                      Authors           Post Date    Post ID  \
# 962    Nanticha Ocharoenchai 2019-05-01 02:36:13  grp000962
# 1031  Rashini Suriyaarachchi 2018-10-09 05:06:43  grp001031
# 1210            Reyes Tirado 2017-01-13 00:31:00  grp001210
#
#                          Category  \
# 962   Social and Economic Systems
# 1031  Social and Economic Systems
# 1210                       Nature
#
#                                                    Text
# 962        All it took was determination and initiative
# 1031  Many of us think about the impacts of climate ...
# 1210  “Ojos hacen fe.” Those are the words of Lucy M...

# %% [markdown]
# To address your request, I will update the `df_grp` DataFrame by removing the rows that are present in the `df_grp_single_paragraph` DataFrame, effectively filtering out posts consisting of only a single paragraph.

# %%
# Drop the rows identified by df_grp_single_paragraph from df_grp
df_grp = df_grp.drop(df_grp_single_paragraph.index)
df_grp
# Out:
#           Source Post Term           Post Tags  \
# 0     Greenpeace   Stories         Photography
# 1     Greenpeace   Stories             Forests
# 2     Greenpeace   Stories  AlternativeFutures
# 3     Greenpeace   Stories         Photography
# 4     Greenpeace   Stories      Peace, Nuclear
# ...          ...       ...                 ...
# 1352  Greenpeace   Stories    AboutUs, 50Years
# 1353  Greenpeace   Stories    AboutUs, 50Years
# 1354  Greenpeace   Stories    AboutUs, 50Years
# 1355  Greenpeace   Stories    AboutUs, 50Years
# 1356  Greenpeace   Stories    AboutUs, 50Years
#
#                                                   Title  \
# 0                       Greenpeace Pictures of the Week
# 1     Environmental storytelling for a Chinese audie...
# 2     5 reasons Greenpeace calls for new global tax ...
# 3                       Greenpeace Pictures of the Week
# 4               From Hiroshima to Gaza: defending peace
# ...                                                 ...
# 1352                          Dorothy Stowe 1920 – 2010
# 1353                             Jim Bohlen 1926 – 2010
# 1354             A chat with the first Rainbow Warriors
# 1355                      Amchitka: the founding voyage
# 1356                             Bob Hunter 1941 – 2005
#
#                                                Post URL  \
# 0     https://www.greenpeace.org/international/story...
# 1     https://www.greenpeace.org/international/story...
# 2     https://www.greenpeace.org/international/story...
# 3     https://www.greenpeace.org/international/story...
# 4     https://www.greenpeace.org/international/story...
# ...                                                 ...
# 1352  https://www.greenpeace.org/international/story...
# 1353  https://www.greenpeace.org/international/story...
# 1354  https://www.greenpeace.org/international/story...
# 1355  https://www.greenpeace.org/international/story...
# 1356  https://www.greenpeace.org/international/story...
#
#                        Authors           Post Date    Post ID  \
# 0     Greenpeace International 2025-08-15 01:45:33  grp000000
# 1                  August Rick 2025-08-14 01:40:25  grp000001
# 2                   Nina Stros 2025-08-13 13:47:04  grp000002
# 3     Greenpeace International 2025-08-08 05:09:19  grp000003
# 4            Greenpeace France 2025-08-07 15:22:58  grp000004
# ...                        ...                 ...        ...
# 1352                Rex Weyler 2010-07-23 07:48:13  grp001352
# 1353  Greenpeace International 2010-07-06 08:06:09  grp001353
# 1354         Michael Friedrich 2007-06-24 12:03:00  grp001354
# 1355  Greenpeace International 2007-05-14 13:56:16  grp001355
# 1356  Greenpeace International 2005-05-02 15:15:00  grp001356
#
#                          Category  \
# 0                      Greenpeace
# 1                          Nature
# 2     Social and Economic Systems
# 3                      Greenpeace
# 4                          Energy
# ...                           ...
# 1352                   Greenpeace
# 1353                   Greenpeace
# 1354                   Greenpeace
# 1355                   Greenpeace
# 1356                   Greenpeace
#
#                                                    Text
# 0     From a banner protest at the plastic treaty in...
# 1     Liu Min, better known as “Aunt Bear”, was one ...
# 2     Smoke from the Canadian wildfires drifting thr...
# 3     From a demonstration at the plastic treaty in ...
# 4     On August 6 and 9, 1945, two atomic bombs pulv...
# ...                                                 ...
# 1352  Greenpeace co-founder Dorothy Stowe passed awa...
# 1353  There’s an old joke that you can walk into any...
# 1354  In Vancouver, on Canada’s Pacific coast, Green...
# 1355  In 1971, a small group of activists set sail t...
# 1356  Perhaps more than anyone else, Bob Hunter inve...
#
# [1354 rows x 10 columns]

# %% [markdown]
# ### Slice the `df_grp` DataFrame to extract a sample of 1,000 blog posts

# %% [markdown]
# To address your request, I will first filter the `df_grp` DataFrame to exclude rows with a `Post Date` on or after November 30, 2022. Then, I will select the first 1,000 rows from this filtered dataset to create the `df_grp_1000` DataFrame.

# %%
# First, slice df_grp by dropping the rows whose Post Date dates are after or equal to 2022-11-30
# This retains rows strictly before that date
df_grp_sliced = df_grp[df_grp['Post Date'] < '2022-12-01']

# Then, from this first slice, slice the first 1,000 rows
df_grp_1000 = df_grp_sliced.iloc[:1000]

df_grp_1000
# Out:
#           Source Post Term                 Post Tags  \
# 438   Greenpeace   Stories  Climate, Forests, Oceans
# 439   Greenpeace   Stories                      Wins
# 440   Greenpeace   Stories          EnergyRevolution
# 441   Greenpeace   Stories               Consumption
# 442   Greenpeace   Stories              Food, Oceans
# ...          ...       ...                       ...
# 1352  Greenpeace   Stories          AboutUs, 50Years
# 1353  Greenpeace   Stories          AboutUs, 50Years
# 1354  Greenpeace   Stories          AboutUs, 50Years
# 1355  Greenpeace   Stories          AboutUs, 50Years
# 1356  Greenpeace   Stories          AboutUs, 50Years
#
#                                                   Title  \
# 438    3 demands we’re making for biodiversity at COP15
# 439   Good news stories from around the world – Nove...
# 440   Big oil’s generational curse: pollutant-relate...
# 441           Black Friday: My nightmare for the planet
# 442             Sailing 1,000 km to save Thai mackerels
# ...                                                 ...
# 1352                          Dorothy Stowe 1920 – 2010
# 1353                             Jim Bohlen 1926 – 2010
# 1354             A chat with the first Rainbow Warriors
# 1355                      Amchitka: the founding voyage
# 1356                             Bob Hunter 1941 – 2005
#
#                                                Post URL  \
# 438   https://www.greenpeace.org/international/story...
# 439   https://www.greenpeace.org/international/story...
# 440   https://www.greenpeace.org/international/story...
# 441   https://www.greenpeace.org/international/story...
# 442   https://www.greenpeace.org/international/story...
# ...                                                 ...
# 1352  https://www.greenpeace.org/international/story...
# 1353  https://www.greenpeace.org/international/story...
# 1354  https://www.greenpeace.org/international/story...
# 1355  https://www.greenpeace.org/international/story...
# 1356  https://www.greenpeace.org/international/story...
#
#                        Authors           Post Date    Post ID    Category  \
# 438            Agnès Le Rouzic 2022-11-30 18:52:08  grp000438      Nature
# 439   Greenpeace International 2022-11-30 00:44:39  grp000439  Greenpeace
# 440                Angelo Louw 2022-11-28 10:36:13  grp000440      Energy
# 441       Alessandro Saccoccio 2022-11-25 10:16:31  grp000441  Greenpeace
# 442           Songwut Jullanan 2022-11-25 04:51:12  grp000442      Nature
# ...                        ...                 ...        ...         ...
# 1352                Rex Weyler 2010-07-23 07:48:13  grp001352  Greenpeace
# 1353  Greenpeace International 2010-07-06 08:06:09  grp001353  Greenpeace
# 1354         Michael Friedrich 2007-06-24 12:03:00  grp001354  Greenpeace
# 1355  Greenpeace International 2007-05-14 13:56:16  grp001355  Greenpeace
# 1356  Greenpeace International 2005-05-02 15:15:00  grp001356  Greenpeace
#
#                                                    Text
# 438   We are at a crucial turning point for the futu...
# 439   Citizens win the second round of an air pollut...
# 440   Not much has changed in the 40 years since Sha...
# 441   I’ve had a recurring nightmare lately. In the ...
# 442   Mackerel is the soul food of the Thai nation. ...
# ...                                                 ...
# 1352  Greenpeace co-founder Dorothy Stowe passed awa...
# 1353  There’s an old joke that you can walk into any...
# 1354  In Vancouver, on Canada’s Pacific coast, Green...
# 1355  In 1971, a small group of activists set sail t...
# 1356  Perhaps more than anyone else, Bob Hunter inve...
#
# [916 rows x 10 columns]

# %% [markdown]
# This slice results in less than 1,000 blog posts. Therefore, it is necessary to relax the requirement to include blog posts posted after 30/11/2022.

# %%
# Slice the last 1,000 rows
df_grp_1000 = df_grp.iloc[-1000:]

df_grp_1000
# Out:
#           Source Post Term                                          Post Tags  \
# 354   Greenpeace   Stories                                             Oceans
# 355   Greenpeace   Stories                        Climate, AlternativeFutures
# 356   Greenpeace   Stories  Climate, Fires, Forests, ExtremeWeather, Photo...
# 357   Greenpeace   Stories                                   EnergyRevolution
# 358   Greenpeace   Stories                                      Climate, Food
# ...          ...       ...                                                ...
# 1352  Greenpeace   Stories                                   AboutUs, 50Years
# 1353  Greenpeace   Stories                                   AboutUs, 50Years
# 1354  Greenpeace   Stories                                   AboutUs, 50Years
# 1355  Greenpeace   Stories                                   AboutUs, 50Years
# 1356  Greenpeace   Stories                                   AboutUs, 50Years
#
#                                                   Title  \
# 354   Whales always had voices. Roger Payne helped t...
# 355   The creativity of youth is changing mindsets o...
# 356     Climate emergencies photos from the year so far
# 357   Young professionals take on South Africa’s ene...
# 358                              10 big secrets of bees
# ...                                                 ...
# 1352                          Dorothy Stowe 1920 – 2010
# 1353                             Jim Bohlen 1926 – 2010
# 1354             A chat with the first Rainbow Warriors
# 1355                      Amchitka: the founding voyage
# 1356                             Bob Hunter 1941 – 2005
#
#                                                Post URL  \
# 354   https://www.greenpeace.org/international/story...
# 355   https://www.greenpeace.org/international/story...
# 356   https://www.greenpeace.org/international/story...
# 357   https://www.greenpeace.org/international/story...
# 358   https://www.greenpeace.org/international/story...
# ...                                                 ...
# 1352  https://www.greenpeace.org/international/story...
# 1353  https://www.greenpeace.org/international/story...
# 1354  https://www.greenpeace.org/international/story...
# 1355  https://www.greenpeace.org/international/story...
# 1356  https://www.greenpeace.org/international/story...
#
#                                 Authors           Post Date    Post ID  \
# 354                     Chris Greenberg 2023-06-13 19:47:42  grp000354
# 355   Renata Nitta and Fabian Ogochukwu 2023-06-09 10:48:57  grp000355
# 356                  Sudhanshu Malhotra 2023-06-05 05:26:30  grp000356
# 357   Jeanette Meyer & Ellie Kouremenou 2023-06-02 10:59:58  grp000357
# 358                Greenpeace East Asia 2023-06-02 05:07:28  grp000358
# ...                                 ...                 ...        ...
# 1352                         Rex Weyler 2010-07-23 07:48:13  grp001352
# 1353           Greenpeace International 2010-07-06 08:06:09  grp001353
# 1354                  Michael Friedrich 2007-06-24 12:03:00  grp001354
# 1355           Greenpeace International 2007-05-14 13:56:16  grp001355
# 1356           Greenpeace International 2005-05-02 15:15:00  grp001356
#
#                          Category  \
# 354                    Greenpeace
# 355   Social and Economic Systems
# 356                        Energy
# 357                        Energy
# 358                        Nature
# ...                           ...
# 1352                   Greenpeace
# 1353                   Greenpeace
# 1354                   Greenpeace
# 1355                   Greenpeace
# 1356                   Greenpeace
#
#                                                    Text
# 354   Whales could always speak for themselves. Huma...
# 355   All over the world people are coming together ...
# 356   As we celebrate World Environment Day today, i...
# 357   In South Africa, Common Power is uplifting com...
# 358   This story was originally posted by Greenpeace...
# ...                                                 ...
# 1352  Greenpeace co-founder Dorothy Stowe passed awa...
# 1353  There’s an old joke that you can walk into any...
# 1354  In Vancouver, on Canada’s Pacific coast, Green...
# 1355  In 1971, a small group of activists set sail t...
# 1356  Perhaps more than anyone else, Bob Hunter inve...
#
# [1000 rows x 10 columns]

# %% [markdown]
# #### Export to a file

# %%
df_grp_1000.to_json(f"{output_directory}/{dataset_filename_3}.jsonl", orient='records', lines=True)

# %% [markdown]
# ### Extract the blog posts

# %% [markdown]
# #### Import the data into a DataFrame

# %%
df_grp_1000 = pd.read_json(f"{output_directory}/{dataset_filename_3}.jsonl", lines=True)

# %%
df_grp_1000['Post Date'] = pd.to_datetime(df_grp_1000['Post Date'], unit='ms')

# %%
df_grp_1000
# Out:
#          Source Post Term                                          Post Tags  \
# 0    Greenpeace   Stories                                             Oceans
# 1    Greenpeace   Stories                        Climate, AlternativeFutures
# 2    Greenpeace   Stories  Climate, Fires, Forests, ExtremeWeather, Photo...
# 3    Greenpeace   Stories                                   EnergyRevolution
# 4    Greenpeace   Stories                                      Climate, Food
# ..          ...       ...                                                ...
# 995  Greenpeace   Stories                                   AboutUs, 50Years
# 996  Greenpeace   Stories                                   AboutUs, 50Years
# 997  Greenpeace   Stories                                   AboutUs, 50Years
# 998  Greenpeace   Stories                                   AboutUs, 50Years
# 999  Greenpeace   Stories                                   AboutUs, 50Years
#
#                                                  Title  \
# 0    Whales always had voices. Roger Payne helped t...
# 1    The creativity of youth is changing mindsets o...
# 2      Climate emergencies photos from the year so far
# 3    Young professionals take on South Africa’s ene...
# 4                               10 big secrets of bees
# ..                                                 ...
# 995                          Dorothy Stowe 1920 – 2010
# 996                             Jim Bohlen 1926 – 2010
# 997             A chat with the first Rainbow Warriors
# 998                      Amchitka: the founding voyage
# 999                             Bob Hunter 1941 – 2005
#
#                                               Post URL  \
# 0    https://www.greenpeace.org/international/story...
# 1    https://www.greenpeace.org/international/story...
# 2    https://www.greenpeace.org/international/story...
# 3    https://www.greenpeace.org/international/story...
# 4    https://www.greenpeace.org/international/story...
# ..                                                 ...
# 995  https://www.greenpeace.org/international/story...
# 996  https://www.greenpeace.org/international/story...
# 997  https://www.greenpeace.org/international/story...
# 998  https://www.greenpeace.org/international/story...
# 999  https://www.greenpeace.org/international/story...
#
#                                Authors           Post Date    Post ID  \
# 0                      Chris Greenberg 2023-06-13 19:47:42  grp000354
# 1    Renata Nitta and Fabian Ogochukwu 2023-06-09 10:48:57  grp000355
# 2                   Sudhanshu Malhotra 2023-06-05 05:26:30  grp000356
# 3    Jeanette Meyer & Ellie Kouremenou 2023-06-02 10:59:58  grp000357
# 4                 Greenpeace East Asia 2023-06-02 05:07:28  grp000358
# ..                                 ...                 ...        ...
# 995                         Rex Weyler 2010-07-23 07:48:13  grp001352
# 996           Greenpeace International 2010-07-06 08:06:09  grp001353
# 997                  Michael Friedrich 2007-06-24 12:03:00  grp001354
# 998           Greenpeace International 2007-05-14 13:56:16  grp001355
# 999           Greenpeace International 2005-05-02 15:15:00  grp001356
#
#                         Category  \
# 0                     Greenpeace
# 1    Social and Economic Systems
# 2                         Energy
# 3                         Energy
# 4                         Nature
# ..                           ...
# 995                   Greenpeace
# 996                   Greenpeace
# 997                   Greenpeace
# 998                   Greenpeace
# 999                   Greenpeace
#
#                                                   Text
# 0    Whales could always speak for themselves. Huma...
# 1    All over the world people are coming together ...
# 2    As we celebrate World Environment Day today, i...
# 3    In South Africa, Common Power is uplifting com...
# 4    This story was originally posted by Greenpeace...
# ..                                                 ...
# 995  Greenpeace co-founder Dorothy Stowe passed awa...
# 996  There’s an old joke that you can walk into any...
# 997  In Vancouver, on Canada’s Pacific coast, Green...
# 998  In 1971, a small group of activists set sail t...
# 999  Perhaps more than anyone else, Bob Hunter inve...
#
# [1000 rows x 10 columns]

# %% [markdown]
# #### Extract the posts

# %% [markdown]
# <llm-snippet-file>cl_st2_ph2_arianne.ipynb</llm-snippet-file>

# %%
for index, row in df_grp_1000.iterrows():
    file_name = f"{row['Post ID']}.txt"
    file_path = os.path.join(path, file_name)
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(row['Text'])

print(f'Successfully saved {len(df_grp_1000)} text files to {path}.')
# Out:
# Successfully saved 1000 text files to cl_st2_ph2_arianne/grp/02_extracted.
